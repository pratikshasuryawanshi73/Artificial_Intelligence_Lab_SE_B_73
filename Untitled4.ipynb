# %% [markdown]
# <a href="https://colab.research.google.com/github/pratikshasuryawanshi73/Artificial_Intelligence_Lab_SE_B_73/blob/master/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %% [markdown]
# intializing array

# %%
a = np.array([1, 2, 3, 4, 5, 6])
a
# Out:
# array([1, 2, 3, 4, 5, 6])

# %% [markdown]
# accessing elements

# %%
a[2]
# Out:
# np.int64(3)

# %% [markdown]
# 2D array

# %%
a=np.array([[1, 2, 3], [4, 5, 6]])
a
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
l1=[1, 2, 3]
l2=[4, 5, 6]
a=np.array([l1, l2])
a
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
a.ndim
# Out:
# 2

# %%
a.shape
# Out:
# (2, 3)

# %%
a.size
# Out:
# 6

# %%
a.dtype
# Out:
# dtype('int64')

# %%
len(a.shape) == a.ndim
# Out:
# True

# %%
np.zeros(2)
# Out:
# array([0., 0.])

# %%
np.ones(2)
# Out:
# array([1., 1.])

# %%
# Create an empty array with 2 elements
np.empty(2)
# Out:
# array([1., 1.])

# %%
np.arange(2, 9, 2)
# Out:
# array([2, 4, 6, 8])

# %%
a = np.arange(6)
print(a)
# Out:
# [0 1 2 3 4 5]

# %%
b = a.reshape(3, 2)
print(b)
# Out:
# [[0 1]
#  [2 3]
#  [4 5]]

# %%
a = np.array([1, 2, 3, 4, 5, 6])
a.shape
# Out:
# (6,)

# %%
data = np.array([[1, 2], [3, 4], [5, 6]])
data
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6]])

# %% [markdown]
# MATRIX

# %%
a=np.array([[1, 2,],[3, 4]])
a
# Out:
# array([[1, 2],
#        [3, 4]])

# %% [markdown]
# determinat of matrix

# %%
np.linalg.det(a)
# Out:
# np.float64(-2.0000000000000004)

# %% [markdown]
# inverse of matrix

# %%
np.linalg.inv(a)
# Out:
# array([[-2. ,  1. ],
#        [ 1.5, -0.5]])

# %% [markdown]
# linear equations using NumPy

# %%
A = np.array([[2, 3], [4, 5]])
B = np.array([10, 20])
X = np.linalg.solve(A, B)
print(X)
# Out:
# [5. 0.]
